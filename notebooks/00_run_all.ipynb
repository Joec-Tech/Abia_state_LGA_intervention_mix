# %% [markdown]
# # Abia SARIMA Malaria Intervention-Mix Model
#
# Run this notebook from the project root. The source files are modularised under `src/` so every assumption can be changed without rewriting the full workflow.
#
# **Date alignment:** The 64 observations map exactly to the 64 monthly periods from **January 2021 through April 2026**. No month is inserted or treated as missing. The 24-month forecast covers **May 2026 through April 2028**.
#
# ## Complete run
#
# This cell rebuilds the dated data, fits 51 stratum-specific SARIMA models, produces the 24-month forecasts, applies all LGA-specific intervention scenarios, calculates costs and generates 17 reports.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
# %cd $PROJECT_ROOT

# %%
from run_pipeline import main
main()

# %%
import pandas as pd
recommendations = pd.read_csv("outputs/tables/government_recommendations.csv")
recommendations

# %% [markdown]
# ## Main outputs
#
# - `outputs/lga_reports/`: 17 four-panel LGA diagrams.
# - `outputs/forecasts/`: monthly 24-month forecasts.
# - `outputs/diagnostics/`: selected SARIMA models, validation metrics and candidate models.
# - `outputs/tables/`: scenarios, costs, recommendations and source tables.
